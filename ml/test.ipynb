# %% [markdown]
# <a href="https://colab.research.google.com/github/banulaperera/SDGP_PT_Y3_03_Intellectia/blob/colab_test/ml/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
test = "test2"
test
# Out:
# 'test2'
